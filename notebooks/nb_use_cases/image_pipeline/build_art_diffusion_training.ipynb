# %%
from shared_code.utility.schemas.spark_table_schema import image_table_schema,image_table_schema_with_caption_tokens
from shared_code.utility.spark.set_environ import *
from shared_code.utility.storage.blob import BlobAdapter

from torch.utils.data import Dataset, random_split
from simpletransformers.language_modeling import LanguageModelingModel
from transformers import GPT2Tokenizer, GPT2LMHeadModel, GPT2Model
from transformers import TrainingArguments, Trainer
import os
import pandas
import torch
import gc
import logging
import random


os.environ["WANDB_DISABLED"] = "true"
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

set_azure_env()

spark = get_session('nature-city-ai')

# %%
from pyspark.sql.functions import count, desc
from pyspark import F

spark_frame = spark.read.csv("D:\\data\\processed\\manifest.csv", header=True)

print(f"== Reading {spark_frame.count()} rows from manifest.csv ==")

grouped_frame = spark_frame.groupby("sub").agg(count("name"))

foo = spark_frame.join(grouped_frame, on="sub", how="inner").select("sub", "count(name)").orderBy(desc("count(name)")).distinct()

print("== Distinct Subreddits ==")
display(foo.toPandas())
# Out:
# == Reading 4638 rows from manifest.csv ==
# == Distinct Subreddits ==
#                  sub  count(name)
# 0           CityPorn          624
# 1        SFWRedheads          821
# 2    SelfiesGoneMild            2
# 3            selfies           76
# 4          sfwpetite          299
# 5            Amicute           83
# 6   SFWNextDoorGirls          846
# 7              Faces          368
# 8    HotGirlNextDoor          342
# 9             amihot          114
# 10          AmIhotAF          349
# 11         greentext           89
# 12         EarthPorn          625

# %%
print("== Reading images from blob ==")
blob: BlobAdapter = BlobAdapter("unprocessed")

data_df = spark_frame.where("sub = 'EarthPorn' or sub = 'CityPorn'").select("name", "sub", "caption", "text")

print("== Images For Subreddits EarthPorn and CityPorn ==")
display(data_df.toPandas())
# Out:
# == Reading images from blob ==
#                    name        sub  \
# 0     3rog9ik4v2ia1.jpg  EarthPorn
# 1     q61cqjmce4ia1.jpg  EarthPorn
# 2     jr75kz7ir7ia1.jpg   CityPorn
# 3     ijebuyn8k6ia1.jpg   CityPorn
# 4     xzxj3tu948ia1.jpg   CityPorn
# ...                 ...        ...
# 1244  j20bptuca2ja1.jpg   CityPorn
# 1245  zq595awts3ja1.jpg   CityPorn
# 1246  lqvtbf9y24ja1.jpg  EarthPorn
# 1247  0vdw42iio2ja1.jpg  EarthPorn
# 1248  vbyxqrv394ja1.jpg  EarthPorn
#
#                                                 caption  \
# 0                a tree stump in the middle of a forest
# 1     a beach scene with the sun setting on the horizon
# 2                a yellow fire hydrant on a city street
# 3       a large building with a clock on the side of it
# 4     a statue of an american flag on top of a city ...
# ...                                                 ...
# 1244      an old photo of a town with lots of buildings
# 1245          a tall building with a clock on top of it
# 1246         a small group of wildflowers on a hillside
# 1247                   a herd of wildflowers in a field
# 1248             a tree in the middle of a grassy field
#
#                                                    text
# 0     Trees Holding Hands. Lyman, ME USA [1080×1920]...
# 1     Praia Grande - SP, Brazil (4160x3120) Where th...
# 2                                           Chicago, IL
# 3                                          Forli, Italy
# 4                      Piazza San Marco, Venezia, Italy
# ...                                                 ...
# 1244                                  Boston, MA (1860)
# 1245                                   W HOTEL Building
# 1246  California poppies along a trail in Eagle Peak...
# 1247  Afternoon Crocus bloom in the Pacific Northwes...
# 1248                 Morning on a lake [OC] [4161x3121]
#
# [1249 rows x 4 columns]

# %%
# !mkdir -p images
# Out:
# A subdirectory or file images already exists.
# Error occurred while processing: images.

# %%
import shutil

df_1 = spark.createDataFrame(data_df.withColumnRenamed("name", "file_name").collect()).select("file_name", "text").toPandas().to_json(orient='records', lines=True)

foo = data_df.select("sub", "name").rdd.map(lambda x: f"D:\\data\\images\\{x.sub}\\thumbnail\\{x.name}").collect()

for elem in foo:
    if os.path.exists(elem):
        print(f"Copying {elem}")
        shutil.copy(elem, "images")
    else:
        print(f"File {elem} does not exist")

with open('metadata.jsonl', 'w', encoding='utf-8') as f:
    f.write(df_1)

shutil.copy("metadata.jsonl", "images")
# Out:
# Copying D:\data\images\EarthPorn\thumbnail\3rog9ik4v2ia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\q61cqjmce4ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\jr75kz7ir7ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\ijebuyn8k6ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\xzxj3tu948ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\oztl2k17t6ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\ptbcvl87u6ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\u34q7hf0e8ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\f5jwju9qf8ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\i5tt4i43k8ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\xwme1arla7ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\sa2loj1ad7ia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\foa3qj6f09ia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\cabitja3j7ia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\gubgu1guj7ia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\9abctoyl49ia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\fczrosija9ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\igtm8w00c9ia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\ewpajaioe9ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\4ydbr53658ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\llm1litvm9ia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\lkugjclyq9ia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\zf9qETk.jpg
# Copying D:\data\images\EarthPorn\thumbnail\3n8jwi4c3aia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\2nn6szz9baia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\99rlyzodeaia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\bNcDnFd.jpg
# Copying D:\data\images\EarthPorn\thumbnail\aia3k3mfsaia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\zpf6qo64n9ia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\yDSZubj.jpg
# Copying D:\data\images\CityPorn\thumbnail\srbeql81hbia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\lqkbmznjmbia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\wrcclzv7vbia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\ma63ech9ccia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\0wforev6fcia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\io2gs6tmxaia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\h7kqiyscicia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\sdlqog30abia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\KUKVm82.jpg
# Copying D:\data\images\EarthPorn\thumbnail\dn6bqga29dia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\2rdawl2ljdia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\yp13pfuopdia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\ilntrqyawdia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\q6qtltyehcia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\6ymbcahcicia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\jo4tGzY.jpg
# Copying D:\data\images\EarthPorn\thumbnail\u4kgbsy9lcia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\izvvjfi77eia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\n4w2an6c9eia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\g3tklvoxucia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\wOfuqJ8.jpg
# Copying D:\data\images\CityPorn\thumbnail\wilwtu119dia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\0ozGTKo.jpg
# Copying D:\data\images\EarthPorn\thumbnail\5hixrakpcdia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\e4sn9pdxfdia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\8542uph81fia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\y4h8jn9zldia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\8xh34z0hndia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\iuc1jcxf7fia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\is6hz0b79fia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\U8GP6DI.jpg
# Copying D:\data\images\CityPorn\thumbnail\a8ase4vfafia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\Gl9aKah.jpg
# Copying D:\data\images\CityPorn\thumbnail\z4nytlcvbfia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\28po87algfia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\fi2bj6muzdia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\ku70qn87nfia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\52cwcn9naeia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\hp06fndqeeia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\7ltpoxp7jeia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\jpajao412gia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\ke76z65yjeia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\rf14hd0u5gia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\1p49kmt89gia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\0zfmqaw2yeia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\riq7b64iggia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\87zkfafr2fia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\kaqsrceumgia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\ymcncxa3ogia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\olimpm5q7fia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\w5mxvn8fpgia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\k1nkfed0qgia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\8czU5OC.jpg
# Copying D:\data\images\EarthPorn\thumbnail\bb9t107rtgia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\UYdpgFl.jpg
# Copying D:\data\images\CityPorn\thumbnail\h7kc612svgia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\7PINkky.jpg
# Copying D:\data\images\EarthPorn\thumbnail\qg2tp9gqffia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\3icomhjd2hia1.jpg
# Copying D:\data\images\CityPorn\thumbnail\6i1p931f9hia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\gNLzVch.jpg
# Copying D:\data\images\EarthPorn\thumbnail\vi4cw00sghia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\cu6vyrgp2gia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\7uqc5oklkhia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\tftlndzflhia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\g8owvv6i5gia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\t8y3gm1lohia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\cq15rpxxdgia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\i2hcvu5pyhia1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\
1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\yajqa5o2jhga1.jpg
# Copying D:\data\images\CityPorn\thumbnail\h7hx85cr3gga1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\z3l9lz2ylhga1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\yhojdsP.jpg
# Copying D:\data\images\EarthPorn\thumbnail\xum8emvimhga1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\5cmhzg8rmhga1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\0klornlnnhga1.jpg
# Copying D:\data\images\CityPorn\thumbnail\g5xhw3ypqhga1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\osj9dgpv9gga1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\34gvfvkvcgga1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\gywhxqarcgga1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\60srpiq2zhga1.jpg
# Copying D:\data\images\CityPorn\thumbnail\epGHRnF.jpg
# Copying D:\data\images\CityPorn\thumbnail\idhe2gzezhga1.jpg
# Copying D:\data\images\CityPorn\thumbnail\Y86m6xp.jpg
# Copying D:\data\images\CityPorn\thumbnail\57b0calc4iga1.jpg
# Copying D:\data\images\CityPorn\thumbnail\fpy022en4iga1.jpg
# Copying D:\data\images\CityPorn\thumbnail\po6nvnda349a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\506xlwvf449a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\u5cui6m8e49a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\c0ks9jcbf49a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\wlafdecs139a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\c5cf4ggws49a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\9h77tnnvb39a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\oazufyfcv49a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\e28BtTX.jpg
# Copying D:\data\images\CityPorn\thumbnail\52399522034_be5f3f4c6a_6k.jpg
# Copying D:\data\images\CityPorn\thumbnail\gf0ykkcer39a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\jlun5lrha59a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\hj6nxkrha59a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\46dlhgr4w39a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\63kwj41dh59a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\paxy05dbo59a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\007jq3cds59a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\7b7gs3mvs59a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\5cw0kc36a69a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\eqsb9n2ky49a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\357kb2s6q69a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\2bhbe0ib779a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\3yzkqeeji69a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\sVzrJxW.jpg
# Copying D:\data\images\CityPorn\thumbnail\6869buih599a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\2j7xm7z2j99a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\42vv9vzxl99a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\ck3h7zu2m99a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\k1icmryvo99a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\53bl7y94q99a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\76qjcf59x99a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\h2isu899y99a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\rgj7fwhsh89a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\635j4gvln89a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\8LdNxay.jpg
# Copying D:\data\images\CityPorn\thumbnail\bG9GZA5.jpg
# Copying D:\data\images\CityPorn\thumbnail\1py695fqaa9a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\dwu7i1dni99a1.jpg
# Copying D:\data\images\CityPorn\thumbnail\4akp14fdr2ja1.jpg
# Copying D:\data\images\CityPorn\thumbnail\ub9gj415y2ja1.jpg
# Copying D:\data\images\CityPorn\thumbnail\86565togn1ja1.jpg
# Copying D:\data\images\CityPorn\thumbnail\vps5abyn73ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\wa4hwk7o73ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\vkga0ttgq1ja1.jpg
# Copying D:\data\images\CityPorn\thumbnail\hrd9029t93ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\2448d7mbb3ja1.jpg
# Copying D:\data\images\CityPorn\thumbnail\xv0y1gr4c3ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\vvr9oro2d3ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\6ofgr6l6e3ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\o4xk57ybe3ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\pc52i3l4w1ja1.jpg
# Copying D:\data\images\CityPorn\thumbnail\l88tyzt1y1ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\eo9x1tvby1ja1.jpg
# Copying D:\data\images\CityPorn\thumbnail\v5le737vj3ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\zvvvs53m42ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\im7jbl9s62ja1.jpg
# Copying D:\data\images\CityPorn\thumbnail\j20bptuca2ja1.jpg
# Copying D:\data\images\CityPorn\thumbnail\zq595awts3ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\lqvtbf9y24ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\0vdw42iio2ja1.jpg
# Copying D:\data\images\EarthPorn\thumbnail\vbyxqrv394ja1.jpg
# 'images\\metadata.jsonl'

# %%
# !tar -a -c -f out.zip images

# %%
text_lines = list(data_df.select("text").rdd.map(lambda x: x.text).collect())

with open("training.txt", "wb") as f:
    for text_line in text_lines:
        line = "<|startoftext|>" + f"{text_line}" + "<|endoftext|>" + "\n"
        f.write(line.encode("utf-8"))

# %%
model_type = ""

model_name = f"nature-prompt-bot{model_type}"

parent_directory = "/content/MyDrive/RawData/model_base"

model_output_dir = f"{parent_directory}/{model_name}"

tokenizer_path = f"{model_output_dir}"

# %%
class CustomDataset(Dataset):
	_input_id: str = 'input_ids'
	_attention_mask: str = 'attention_mask'

	def __init__(self, text_list, tokenizer, max_length, truncation=False):
		self.input_ids = []
		self.attention_mask = []
		self.labels = []
		for text in text_list:
			encodings_dict = tokenizer(text, truncation=truncation, max_length=max_length)
			self.input_ids.append(torch.tensor(encodings_dict[self._input_id]))
			self.attention_mask.append(torch.tensor(encodings_dict[self._attention_mask]))

	def __len__(self):
		return len(self.input_ids)

	def __getitem__(self, index):
		return self.input_ids[index], self.attention_mask[index]

# %%
data_lines = []
with open('training.txt', 'r', encoding="UTF-8") as f:
	lines = f.readlines()
	for line in lines:
		foo = line
		print(foo)
		data_lines.append(foo)

random.shuffle(data_lines)

# %%
tokenizer = GPT2Tokenizer.from_pretrained(f"gpt2{model_type}")

model = GPT2LMHeadModel.from_pretrained(f"gpt2{model_type}")

special_tokens_dict = {
    "bos_token": "<|startoftext|>",
    "eos_token": "<|endoftext|>",
    "additional_special_tokens": [
        "<|endoftext|>",
        "<|startoftext|>"
    ]
}

print(tokenizer.eos_token)

num_added_toks = tokenizer.add_special_tokens(special_tokens_dict)

print("We have added", num_added_toks, "tokens")

print(tokenizer.eos_token)

# Notice: resize_token_embeddings expect to receive the full size of the new vocabulary, i.e., the length of the tokenizer.
model.resize_token_embeddings(len(tokenizer))

model.save_pretrained(model_output_dir)

tokenizer.save_pretrained(tokenizer_path)

model = GPT2LMHeadModel.from_pretrained(model_output_dir)

tokenizer = GPT2Tokenizer.from_pretrained(tokenizer_path)

model.cuda()

# %%
generator = torch.Generator()

generator.manual_seed(0)

print(f":: Total Number Of Samples {len(data_lines)}")

max_length = max([len(tokenizer.encode(prompt)) for prompt in data_lines])

print(f":: Max Length Of Sample {max_length}")

dataset = CustomDataset(data_lines, tokenizer, max_length=max_length)

train_size = int(0.9 * len(dataset))

train_dataset, eval_dataset = random_split(dataset, [train_size, len(dataset) - train_size], generator=generator)

# %%
training_args = TrainingArguments(output_dir=model_output_dir)
training_args.num_train_epochs = 5
training_args.per_device_train_batch_size = 1
training_args.per_device_eval_batch_size = 1
training_args.logging_steps=50
training_args.save_steps=1000
training_args.weight_decay=0.0
training_args.logging_dir='./logs'
training_args.fp16=True
training_args.auto_find_batch_size=True
training_args.gradient_accumulation_steps=50
training_args.learning_rate=1e-4

# %%
trainer: Trainer = Trainer(
		model=model,
		args=training_args,
		train_dataset=train_dataset,
		eval_dataset=eval_dataset,
		data_collator=lambda data: {
			'input_ids': torch.stack([f[0] for f in data]),
			'attention_mask': torch.stack([f[1] for f in data]),
			'labels': torch.stack([f[0] for f in data])
		}
	)

# %%
trainer.train()

trainer.save_model(model_output_dir)

# %%
tokenizer = GPT2Tokenizer.from_pretrained(tokenizer_path)

model = GPT2LMHeadModel.from_pretrained(model_output_dir)

# %%
question = "<|startoftext|>"

prompt = f"{question}"

device = torch.device(f"cuda" if torch.cuda.is_available() else "cpu")

generation_prompt = tokenizer(prompt, add_special_tokens=False, return_tensors="pt")

model.to(device)

generation_prompt.to(device)

inputs = generation_prompt.input_ids

attention_mask = generation_prompt['attention_mask']

sample_outputs = model.generate(inputs=inputs,
                                attention_mask=attention_mask,
                                do_sample=True,
                                top_k=0,
                                top_p=0.95,
                                max_length=1024,
                                num_return_sequences=5,
                                repetition_penalty=1.1)

result = ""
for i, sample_output in enumerate(sample_outputs):
    result = tokenizer.decode(sample_output, skip_special_tokens=True)
    print(result)
